# %%
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor, as_completed
import requests
import numpy as np

# %%
votes6 = os.path.join("Cleaned_data", "EP6_clean_data","votes_EP_6.csv")
votes7 = os.path.join("Cleaned_data", "EP7_clean_data","votes_EP_7.csv")
votes8= os.path.join("Cleaned_data", "EP8_clean_data","votes_EP_8.csv")
votes9 =os.path.join("Cleaned_data", "EP9_clean_data","votes_EP_9.csv")
votations6 = os.path.join("Cleaned_data", "EP6_clean_data","votations_EP_6.csv")
votations7 = os.path.join("Cleaned_data", "EP7_clean_data","votations_EP_7.csv")
votations8 = os.path.join("Cleaned_data", "EP8_clean_data","votations_EP_8.csv")
votations9 = os.path.join("Cleaned_data", "EP9_clean_data","votations_EP_9.csv")
mepinfo6 = os.path.join("Cleaned_data", "EP6_clean_data","mep_info_EP_6.csv")
mepinfo7 = os.path.join("Cleaned_data", "EP7_clean_data","mep_info_EP_7.csv")
mepinfo8 = os.path.join("Cleaned_data", "EP8_clean_data","mep_info_EP_8.csv")
mepinfo9 = os.path.join("Cleaned_data", "EP9_clean_data","mep_info_EP_9.csv")

# %%
ep_votes6 = pd.read_csv(votes6)
ep_votes7 = pd.read_csv(votes7)
ep_votes8 = pd.read_csv(votes8)
ep_votes9 = pd.read_csv(votes9)
ep_mepinfo6 = pd.read_csv(mepinfo6)
ep_mepinfo7 = pd.read_csv(mepinfo7)
ep_mepinfo8 = pd.read_csv(mepinfo8)
ep_mepinfo9 = pd.read_csv(mepinfo9)
ep_votations6 = pd.read_csv(votations6)
ep_votations7 = pd.read_csv(votations7)
ep_votations8 = pd.read_csv(votations8)
ep_votations9 = pd.read_csv(votations9)

# %%
votations_combined = votations_combined.astype({'FinalVote': 'Int64', 'Vote': 'Int64',"No":"Int64","Abs":"Int64",})

# %%
ep_votations6 = ep_votations6.astype({'FinalVote': 'Int64', 'Vote': 'Int64',"No":"Int64","Abs":"Int64",})
ep_votations7 = ep_votations7.astype({'FinalVote': 'Int64', 'Vote': 'Int64',"No":"Int64","Abs":"Int64",})
ep_votations8 = ep_votations8.astype({'FinalVote': 'Int64', 'Vote': 'Int64',"No":"Int64","Abs":"Int64",})
ep_votations9 = ep_votations9.astype({'FinalVote': 'Int64', 'Vote': 'Int64',"No":"Int64","Abs":"Int64",})

# %%
ep_votations6.Date = pd.to_datetime(ep_votations6.Date)
ep_votations7.Date = pd.to_datetime(ep_votations7.Date)
ep_votations8.Date = pd.to_datetime(ep_votations8.Date)
ep_votations9.Date = pd.to_datetime(ep_votations9.Date)

# %%
votations_combined.Date = pd.to_datetime(votations_combined.Date)

# %%
votations_combined.dtypes
# Out:
# VoteId                            int64
# Date                     datetime64[ns]
# Title                            object
# Procedure                        object
# Leg/Non-Leg/Bud                  object
# TypeOfVote                       object
# VotingRule                       object
# Rapporteur                       object
# Link                             object
# CommitteeResponsabile            object
# PolicyArea                       object
# Subject                          object
# FinalVote                         Int64
# Author                           object
# AmNo                             object
# Vote                              Int64
# Yes                               int64
# No                                Int64
# Abs                               Int64
# EP_ID                             int64
# dtype: object

# %%
mepinfo_combined = pd.concat([ep_mepinfo6,ep_mepinfo7,ep_mepinfo8,ep_mepinfo9])

# %%
ep_mepinfo6.Start =pd.to_datetime(ep_mepinfo6.Start)
ep_mepinfo7.Start = pd.to_datetime(ep_mepinfo7.Start)
ep_mepinfo8.Start = pd.to_datetime(ep_mepinfo8.Start)
ep_mepinfo9.Start = pd.to_datetime(ep_mepinfo9.Start)

# %%
mepinfo_combined.Start = pd.to_datetime(mepinfo_combined.Start)

# %%
ep_mepinfo6.End = pd.to_datetime(ep_mepinfo6.End)
ep_mepinfo7.End = pd.to_datetime(ep_mepinfo7.End)
ep_mepinfo8.End = pd.to_datetime(ep_mepinfo8.End)
ep_mepinfo9.End = pd.to_datetime(ep_mepinfo9.End)

# %%
ep_votes6 = ep_votes6[['MepId',"VoteId","Vote"]]
ep_votes7 = ep_votes7[['MepId',"VoteId","Vote"]]
ep_votes8 = ep_votes8[['MepId',"VoteId","Vote"]]
ep_votes9 = ep_votes9[['MepId',"VoteId","Vote"]]

# %%
ep_votes6
# Out:
#          MepId  VoteId  Vote
# 0        28469       1     1
# 1        28302       1     5
# 2        28975       1     3
# 3        28367       1     5
# 4        28512       1     5
# ...        ...     ...   ...
# 5827055  95280    6200     5
# 5827056  95281    6200     4
# 5827057  95704    6200     5
# 5827058  96101    6200     4
# 5827059  23852    6200     4
#
# [5827060 rows x 3 columns]

# %%
ep_mepinfo7
# Out:
#       MepId        Fname                        Lname  \
# 0     96850       Damien                         Abad
# 1     96659        János                         Áder
# 2     96897  John Stuart                        Agnew
# 3     28367     Gabriele                    Albertini
# 4     96736  Jan Philipp                     Albrecht
# ..      ...          ...                          ...
# 848  122885   Rina Ronja                         Kari
# 849  123792     Giovanni                   Barbagallo
# 850  123816      Annette                      Koewius
# 851   37200       Katrin                         Saks
# 852  124287    Christine  Revault d'Allonnes Bonnefoy
#
#                                   FullName Activ         Country  \
# 0                              Damien ABAD    no          France
# 1                               János ÁDER    no         Hungary
# 2                        John Stuart AGNEW   yes  United Kingdom
# 3                       Gabriele ALBERTINI    no           Italy
# 4                     Jan Philipp ALBRECHT   yes         Germany
# ..                                     ...   ...             ...
# 848                        Rina Ronja KARI    no         Denmark
# 849                    Giovanni BARBAGALLO    no           Italy
# 850                        Annette KOEWIUS    no         Germany
# 851                            Katrin SAKS    no         Estonia
# 852  Christine REVAULT D'ALLONNES BONNEFOY    no          France
#
#                                                  Party         EPG      Start  \
# 0                                       Nouveau Centre         EPP 2009-07-14
# 1    Fidesz-Magyar Polgári Szövetség-Keresztény Dem...         EPP 2009-07-14
# 2                    United Kingdom Independence Party         EFD 2009-07-14
# 3                              Il Popolo della Libertà         EPP 2009-07-14
# 4                                Bündnis 90/Die Grünen  Greens–EFA 2009-07-14
# ..                                                 ...         ...        ...
# 848                             Folkebevægelsen mod EU     GUE–NGL 2014-02-05
# 849                                Partito Democratico         S&D 2014-03-11
# 850        Christlich Demokratische Union Deutschlands         EPP 2014-03-12
# 851                       Sotsiaaldemokraatlik Erakond         S&D 2014-04-07
# 852                                   Parti socialiste         S&D 2014-04-09
#
#            End  EP_ID
# 0   2012-06-16      7
# 1   2012-05-09      7
# 2   2014-12-31      7
# 3   2013-03-14      7
# 4   2014-12-31      7
# ..         ...    ...
# 848 2014-12-31      7
# 849 2014-12-31      7
# 850 2014-12-31      7
# 851 2014-12-31      7
# 852 2014-12-31      7
#
# [853 rows x 11 columns]

# %%
mepinfo_combined.End = pd.to_datetime(mepinfo_combined.End)

# %%
votes_combined = pd.concat([ep_votes6,ep_votes7,ep_votes8,ep_votes9])

# %%
votes_combined.EP_ID.value_counts()
# Out:
# EP_ID
# 9    10915249
# 8     8796216
# 7     5937733
# 6     5827060
# Name: count, dtype: int64

# %%
base_directory = os.path.join("Cleaned_data","Merged_dataset")
os.makedirs(base_directory, exist_ok=True)

# %%
mepinfo_combined.to_csv(os.path.join(base_directory, "mep_info.csv"), index=False)
votes_combined.to_csv(os.path.join(base_directory, "votes.csv"), index=False)
votations_combined.to_csv(os.path.join(base_directory, "votations.csv"), index=False)

# %%
def get_memberships_database(memberships_df):
    temp_df = memberships_df.copy()
    memberships_database = pd.DataFrame()
    memberships_database['MepId'] = temp_df['identifier']
    memberships_database['OrgId'] = temp_df['org_id']
    memberships_database['Classification'] = temp_df['membershipClassification']
    memberships_database['Start'] = temp_df['memberDuring.startDate']
    memberships_database['End'] = temp_df['memberDuring.endDate']
    memberships_database['Label'] = temp_df['org_label']
    return memberships_database

# %%
def get_memberships_df(mep_df, org_df):
    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(get_membership, identifier) for identifier in mep_df['MepId']]
        results = [future.result() for future in as_completed(futures)]

    memberships_df = pd.concat(results, ignore_index=True)
    memberships_df.rename(columns={'organization': 'org_id'}, inplace=True)
    memberships_df = pd.merge(memberships_df, org_df, on='org_id', how='left')
    return memberships_df

# %%
def get_membership(identifier):
    url = f"https://data.europarl.europa.eu/api/v2/meps/{identifier}?format=application%2Fld%2Bjson"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from URL: {url} - {e}")
        return pd.DataFrame()
    try:
        df = pd.json_normalize(data['data'], record_path=['hasMembership'],meta=['citizenship','bday','hasGender'])
    except ValueError as e:
        print(f"Error parsing JSON data: {e}")
        return pd.DataFrame()  # Return an empty DataFrame on JSON parsing error
    df1 = df[(df['membershipClassification'].isnull()) & (df['role']=="def/ep-roles/MEMBER_PARLIAMENT")]
    df2 = df[df['membershipClassification'].isin(["def/ep-entities/EU_POLITICAL_GROUP","def/ep-entities/NATIONAL_CHAMBER"])]
    df = pd.concat([df1,df2])
    try:
        df = df[['organization','membershipClassification','memberDuring.startDate','memberDuring.endDate','citizenship','bday','hasGender']].copy()
    except KeyError as e:
        df = df[['organization','membershipClassification','memberDuring.startDate','citizenship','bday','hasGender']].copy()
        df.loc[:, 'memberDuring.endDate'] = np.NaN
    df.loc[:,'identifier'] = identifier
    return df

# %%
def get_epgs():
    url = 'https://data.europarl.europa.eu/api/v2/corporate-bodies?body-classification=EU_POLITICAL_GROUP&format=application%2Fld%2Bjson&offset=0'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from URL: {url} - {e}")
        return pd.DataFrame()
    try:
        df = pd.json_normalize(data['data'])
    except ValueError as e:
        print(f"Error parsing JSON data: {e}")
        return pd.DataFrame()  # Return an empty DataFrame on JSON parsing error
    df=df[['id','label']]
    epg_df = df.rename(columns={'id':'org_id',"label":"org_label"})
    return epg_df
def get_parties():
    url = 'https://data.europarl.europa.eu/api/v2/corporate-bodies?body-classification=NATIONAL_CHAMBER&format=application%2Fld%2Bjson&offset=0'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from URL: {url} - {e}")
        return pd.DataFrame()
    try:
        df = pd.json_normalize(data['data'])
    except ValueError as e:
        print(f"Error parsing JSON data: {e}")
        return pd.DataFrame()  # Return an empty DataFrame on JSON parsing error
    df=df[['id','label']]
    party_df = df.rename(columns={'id':'org_id',"label":"org_label"})
    return party_df
def generate_ep_df(ep_number):
    # Create a list of org_ids and org_labels based on the ep_number
    org_ids = [f'org/ep-{i}' for i in range(0, ep_number + 1)]
    org_labels = [f'EP{i}' for i in range(0, ep_number + 1)]

    # Create a DataFrame from the generated lists
    ep_df = pd.DataFrame({'org_id': org_ids, 'org_label': org_labels})
    return ep_df

# %%
def get_memberships_database(memberships_df):
    temp_df = memberships_df.copy()
    memberships_database = pd.DataFrame()
    memberships_database['MepId'] = temp_df['identifier']
    memberships_database['OrgId'] = temp_df['org_id']
    memberships_database['Classification'] = temp_df['membershipClassification']
    memberships_database['Start'] = temp_df['memberDuring.startDate']
    memberships_database['End'] = temp_df['memberDuring.endDate']
    memberships_database['Label'] = temp_df['org_label']
    return memberships_database

# %%
epg_df = get_epgs()
party_df = get_parties()
ep_df = generate_ep_df(9)
org_df = pd.concat([epg_df, party_df,ep_df], ignore_index=True)

# %%
ep_mepinfo7
# Out:
#       MepId        Fname                        Lname  \
# 0     96850       Damien                         Abad
# 1     96659        János                         Áder
# 2     96897  John Stuart                        Agnew
# 3     28367     Gabriele                    Albertini
# 4     96736  Jan Philipp                     Albrecht
# ..      ...          ...                          ...
# 848  122885   Rina Ronja                         Kari
# 849  123792     Giovanni                   Barbagallo
# 850  123816      Annette                      Koewius
# 851   37200       Katrin                         Saks
# 852  124287    Christine  Revault d'Allonnes Bonnefoy
#
#                                   FullName Activ         Country  \
# 0                              Damien ABAD    no          France
# 1                               János ÁDER    no         Hungary
# 2                        John Stuart AGNEW   yes  United Kingdom
# 3                       Gabriele ALBERTINI    no           Italy
# 4                     Jan Philipp ALBRECHT   yes         Germany
# ..                                     ...   ...             ...
# 848                        Rina Ronja KARI    no         Denmark
# 849                    Giovanni BARBAGALLO    no           Italy
# 850                        Annette KOEWIUS    no         Germany
# 851                            Katrin SAKS    no         Estonia
# 852  Christine REVAULT D'ALLONNES BONNEFOY    no          France
#
#                                                  Party         EPG      Start  \
# 0                                       Nouveau Centre         EPP 2009-07-14
# 1    Fidesz-Magyar Polgári Szövetség-Keresztény Dem...         EPP 2009-07-14
# 2                    United Kingdom Independence Party         EFD 2009-07-14
# 3                              Il Popolo della Libertà         EPP 2009-07-14
# 4                                Bündnis 90/Die Grünen  Greens–EFA 2009-07-14
# ..                                                 ...         ...        ...
# 848                             Folkebevægelsen mod EU     GUE–NGL 2014-02-05
# 849                                Partito Democratico         S&D 2014-03-11
# 850        Christlich Demokratische Union Deutschlands         EPP 2014-03-12
# 851                       Sotsiaaldemokraatlik Erakond         S&D 2014-04-07
# 852                                   Parti socialiste         S&D 2014-04-09
#
#            End  EP_ID
# 0   2012-06-16      7
# 1   2012-05-09      7
# 2   2014-12-31      7
# 3   2013-03-14      7
# 4   2014-12-31      7
# ..         ...    ...
# 848 2014-12-31      7
# 849 2014-12-31      7
# 850 2014-12-31      7
# 851 2014-12-31      7
# 852 2014-12-31      7
#
# [853 rows x 11 columns]

# %%
membership6_df = get_memberships_df(ep_mepinfo6,org_df)
membership7_df = get_memberships_df(ep_mepinfo7,org_df)
membership8_df = get_memberships_df(ep_mepinfo8,org_df)
membership9_df = get_memberships_df(ep_mepinfo9,org_df)
# Out:
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28352?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28352?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96990?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96990?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28409?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28409?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96819?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96819?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96664?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96664?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1183?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1183?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97196?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97196?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2278?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2278?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23707?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23707?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96988?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96988?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4294?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4294?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4345?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4345?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96889?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96889?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28404?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28404?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96746?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96746?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2002?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2002?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28295?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28295?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4423?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4423?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96696?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96696?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96815?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96815?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/33989?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/33989?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28297?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28297?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/37312?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/37312?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97308?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97308?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96945?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96945?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4274?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4274?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96864?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96864?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28139?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28139?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28133?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28133?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1930?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1930?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96827?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96827?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96646?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96646?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28223?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28223?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1933?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1933?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96731?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96731?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28135?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28135?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1911?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1911?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96671?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96671?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96843?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96843?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96996?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96996?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96789?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96789?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23787?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23787?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28252?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28252?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/33990?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/33990?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96718?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96718?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96755?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96755?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96865?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96865?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28380?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28380?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96960?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96960?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96932?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96932?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1309?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1309?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96836?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96836?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2081?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2081?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97018?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97018?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28508?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28508?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96655?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96655?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96770?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96770?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4282?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4282?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39724?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39724?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28299?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28299?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/37676?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/37676?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96666?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96666?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97170?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97170?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/997?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/997?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97294?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97294?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28170?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28170?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4751?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4751?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96831?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96831?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97008?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97008?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4243?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4243?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96905?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96905?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4545?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4545?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4546?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4546?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39721?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39721?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/34254?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/34254?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96946?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96946?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96863?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96863?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2037?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2037?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96860?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96860?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28320?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28320?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96766?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96766?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23820?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23820?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96920?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96920?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23821?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23821?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28358?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28358?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96855?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96855?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/36396?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/36396?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28134?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28134?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96678?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96678?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28316?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28316?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2295?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2295?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23808?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23808?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4521?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4521?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/29579?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/29579?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1945?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1945?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97136?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97136?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96821?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96821?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96847?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96847?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96974?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96974?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96727?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96727?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96874?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96874?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/25704?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/25704?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96871?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96871?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39726?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39726?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28153?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28153?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96776?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96776?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1832?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1832?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28584?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28584?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/36281?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/36281?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28340?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28340?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96697?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96697?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97026?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97026?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96909?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96909?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1129?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1129?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28514?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28514?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96713?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96713?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97203?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97203?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96773?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96773?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96898?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96898?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28240?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28240?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96703?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96703?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4432?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4432?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96660?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96660?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28221?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28221?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96672?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96672?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97131?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97131?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96835?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96835?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/38601?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/38601?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1956?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1956?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96845?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96845?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/37324?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/37324?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28617?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28617?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/5729?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/5729?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96858?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96858?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96698?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96698?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4398?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4398?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97019?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97019?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96918?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96918?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4513?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4513?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97058?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97058?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96756?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96756?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4308?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4308?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28177?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28177?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/34232?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/34232?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28323?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28323?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2212?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2212?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/5737?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/5737?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96761?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96761?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96774?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96774?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39713?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39713?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2155?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2155?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28229?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28229?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28227?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28227?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2319?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2319?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4544?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4544?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28130?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28130?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1907?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1907?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97016?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97016?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2323?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2323?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96839?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96839?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/35743?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/35743?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96677?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96677?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96741?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96741?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39725?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39725?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96764?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96764?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96802?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96802?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23784?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23784?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28167?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28167?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28278?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28278?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96944?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96944?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23894?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23894?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23712?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23712?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96656?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96656?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96763?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96763?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/41007?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/41007?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96762?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96762?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96777?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96777?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96778?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96778?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28248?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28248?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28615?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28615?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28619?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28619?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96784?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96784?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96803?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96803?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/28301?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/28301?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/38609?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/38609?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97021?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97021?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/99419?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/99419?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97968?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97968?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/96933?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/96933?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/99416?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/99416?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/99325?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/99325?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/101580?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/101580?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/101954?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/101954?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/102886?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/102886?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23813?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23813?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/103488?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/103488?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/102887?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/102887?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/102931?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/102931?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/105192?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/105192?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/105849?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/105849?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1965?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1965?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/103132?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/103132?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/105624?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/105624?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/5565?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/5565?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/107041?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/107041?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/97344?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/97344?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/2307?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/2307?format=application%2Fld%2BjsonError fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/4562?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/4562?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/107385?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/107385?format=application%2Fld%2Bjson
#
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/23413?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/23413?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/107386?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/107386?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/107973?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/107973?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/108329?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/108329?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/109337?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/109337?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/107977?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/107977?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/108080?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/108080?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/103246?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/103246?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39916?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39916?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/109649?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/109649?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/110365?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/110365?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/1202?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/1202?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/111068?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/111068?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/111126?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/111126?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/110984?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/110984?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/108570?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/108570?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/111026?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/111026?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/111011?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/111011?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/111017?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/111017?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/39321?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/39321?format=application%2Fld%2Bjson
# Error fetching data from URL: https://data.europarl.europa.eu/api/v2/meps/111027?format=application%2Fld%2Bjson - 403 Client Error: Forbidden for url: https://data.europarl.europa.eu/api/v2/meps/111027?format=application%2Fld%2Bjson

# %%
membership6_df = get_memberships_df(ep_mepinfo6,org_df)

# %%
membership6_df
# Out:
#         org_id            membershipClassification memberDuring.startDate  \
# 0     org/ep-6                                 NaN             2004-07-20
# 1     org/ep-5                                 NaN             1999-07-20
# 2     org/ep-7                                 NaN             2009-07-14
# 3     org/1533  def/ep-entities/EU_POLITICAL_GROUP             2004-07-20
# 4      org/994  def/ep-entities/EU_POLITICAL_GROUP             2003-01-10
# ...        ...                                 ...                    ...
# 8403  org/1534  def/ep-entities/EU_POLITICAL_GROUP             2009-01-21
# 8404  org/4284  def/ep-entities/EU_POLITICAL_GROUP             2014-07-01
# 8405  org/2953  def/ep-entities/EU_POLITICAL_GROUP             2009-07-14
# 8406  org/4135    def/ep-entities/NATIONAL_CHAMBER             2014-07-01
# 8407  org/1926    def/ep-entities/NATIONAL_CHAMBER             2009-01-21
#
#      memberDuring.endDate                                        citizenship  \
# 0              2009-07-13  http://publications.europa.eu/resource/authori...
# 1              2004-07-19  http://publications.europa.eu/resource/authori...
# 2              2014-06-30  http://publications.europa.eu/resource/authori...
# 3              2004-08-30  http://publications.europa.eu/resource/authori...
# 4              2004-07-19  http://publications.europa.eu/resource/authori...
# ...                   ...                                                ...
# 8403           2009-07-13  http://publications.europa.eu/resource/authori...
# 8404           2018-01-28  http://publications.europa.eu/resource/authori...
# 8405           2014-06-30  http://publications.europa.eu/resource/authori...
# 8406           2018-01-28  http://publications.europa.eu/resource/authori...
# 8407           2009-07-13  http://publications.europa.eu/resource/authori...
#
#             bday                                          hasGender  \
# 0     1946-02-05  http://publications.europa.eu/resource/authori...
# 1     1946-02-05  http://publications.europa.eu/resource/authori...
# 2     1946-02-05  http://publications.europa.eu/resource/authori...
# 3     1946-02-05  http://publications.europa.eu/resource/authori...
# 4     1946-02-05  http://publications.europa.eu/resource/authori...
# ...          ...                                                ...
# 8403  1963-12-16  http://publications.europa.eu/resource/authori...
# 8404  1963-12-16  http://publications.europa.eu/resource/authori...
# 8405  1963-12-16  http://publications.europa.eu/resource/authori...
# 8406  1963-12-16  http://publications.europa.eu/resource/authori...
# 8407  1963-12-16  http://publications.europa.eu/resource/authori...
#
#       identifier org_label
# 0           4537       EP6
# 1           4537       EP5
# 2           4537       EP7
# 3           4537    PPE-DE
# 4           4537    PPE-DE
# ...          ...       ...
# 8403       95281       PSE
# 8404       95281       S&D
# 8405       95281       S&D
# 8406       95281       PSD
# 8407       95281       PSD
#
# [8408 rows x 9 columns]

# %%
membership8_df = get_memberships_df(ep_mepinfo8,org_df)

# %%
membership8_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 membership8_df
#
# NameError: name 'membership8_df' is not defined

# %%
membership7_df = get_memberships_df(ep_mepinfo7,org_df)

# %%
membership9_df = get_memberships_df(ep_mepinfo9,org_df)

# %%
membership9_df
# Out:
#         org_id            membershipClassification memberDuring.startDate  \
# 0     org/ep-9                                 NaN             2019-07-02
# 1     org/5182    def/ep-entities/NATIONAL_CHAMBER             2019-07-02
# 2     org/5704  def/ep-entities/EU_POLITICAL_GROUP             2019-07-02
# 3     org/ep-9                                 NaN             2019-07-02
# 4     org/5153  def/ep-entities/EU_POLITICAL_GROUP             2019-07-02
# ...        ...                                 ...                    ...
# 4951  org/5196    def/ep-entities/NATIONAL_CHAMBER             2022-02-02
# 4952  org/5154  def/ep-entities/EU_POLITICAL_GROUP             2022-02-02
# 4953  org/ep-9                                 NaN             2022-01-12
# 4954  org/5154  def/ep-entities/EU_POLITICAL_GROUP             2022-01-12
# 4955  org/5270    def/ep-entities/NATIONAL_CHAMBER             2022-01-12
#
#      memberDuring.endDate                                        citizenship  \
# 0                     NaN  http://publications.europa.eu/resource/authori...
# 1              2024-07-15  http://publications.europa.eu/resource/authori...
# 2              2024-07-15  http://publications.europa.eu/resource/authori...
# 3                     NaN  http://publications.europa.eu/resource/authori...
# 4              2024-07-15  http://publications.europa.eu/resource/authori...
# ...                   ...                                                ...
# 4951           2024-07-15  http://publications.europa.eu/resource/authori...
# 4952           2024-07-15  http://publications.europa.eu/resource/authori...
# 4953                  NaN  http://publications.europa.eu/resource/authori...
# 4954           2024-07-15  http://publications.europa.eu/resource/authori...
# 4955           2024-07-15  http://publications.europa.eu/resource/authori...
#
#             bday                                          hasGender  \
# 0     1981-09-18  http://publications.europa.eu/resource/authori...
# 1     1981-09-18  http://publications.europa.eu/resource/authori...
# 2     1981-09-18  http://publications.europa.eu/resource/authori...
# 3     1973-04-10  http://publications.europa.eu/resource/authori...
# 4     1973-04-10  http://publications.europa.eu/resource/authori...
# ...          ...                                                ...
# 4951  1979-11-08  http://publications.europa.eu/resource/authori...
# 4952  1979-11-08  http://publications.europa.eu/resource/authori...
# 4953  1975-05-20  http://publications.europa.eu/resource/authori...
# 4954  1975-05-20  http://publications.europa.eu/resource/authori...
# 4955  1975-05-20  http://publications.europa.eu/resource/authori...
#
#       identifier org_label
# 0         197848       EP9
# 1         197848       DPS
# 2         197848     Renew
# 3         197490       EP9
# 4         197490       PPE
# ...          ...       ...
# 4951      229839       SPD
# 4952      229839       S&D
# 4953      230085       EP9
# 4954      230085       S&D
# 4955      230085        PD
#
# [4956 rows x 9 columns]

# %%
mem9db = get_memberships_database(membership9_df)
mem6db = get_memberships_database(membership6_df)
mem7db = get_memberships_database(membership7_df)
mem8db = get_memberships_database(membership8_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 mem6db = get_memberships_database(membership6_df)
#       3 mem7db = get_memberships_database(membership7_df)
# ----> 4 mem8db = get_memberships_database(membership8_df)
#
# NameError: name 'membership8_df' is not defined
